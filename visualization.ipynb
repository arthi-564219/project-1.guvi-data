# %%
# !pip install plotly
# Out:
# ...
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#    ---------------------------------------- 0.0/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#     --------------------------------------- 0.3/14.8 MB ? eta -:--:--
#    - -------------------------------------- 0.5/14.8 MB 441.7 kB/s eta 0:00:33
#    - -------------------------------------- 0.5/14.8 MB 441.7 kB/s eta 0:00:33
#    -- ------------------------------------- 0.8/14.8 MB 420.3 kB/s eta 0:00:34
#    -- ------------------------------------- 0.8/14.8 MB 420.3 kB/s eta 0:00:34
#    -- ------------------------------------- 0.8/14.8 MB 420.3 kB/s eta 0:00:34
#    -- ------------------------------------- 1.0/14.8 MB 366.5 kB/s eta 0:00:38
#    -- ------------------------------------- 1.0/14.8 MB 366.5 kB/s eta 0:00:38
# ...

# %%
import os

folder_path = r"C:\Users\SATHYA COMPUTERS\Documents\Custom Office Templates\arthi.guvi 1 project"
files = os.listdir(folder_path)
print("Files in folder:\n", files)
# Out:
# Files in folder:
#  ['50 more page .ipynb', 'data', 'visualization.ipynb']

# %%
df = pd.read_csv(r"C:\Users\SATHYA COMPUTERS\Documents\Custom Office Templates\imdb_2024_data.csv")

# %%
df = load_data()
st.write("Columns in title:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:31:55.093 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:31:55.097 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:31:55.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:31:55.103 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:31:55.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:31:55.112 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("Columns in genre:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:32:39.282 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:32:39.285 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:32:39.288 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:32:39.290 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:32:39.293 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:32:39.298 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("Columns in rating:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:33:06.006 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:06.009 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:06.012 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:06.021 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:06.025 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:06.029 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("Columns in voting count:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:33:42.206 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:42.210 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:42.213 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:42.217 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:42.220 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:33:42.223 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("Columns in duration:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:34:01.564 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:34:01.571 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:34:01.573 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:34:01.575 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:34:01.581 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:34:01.589 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("✅ Columns in your dataset:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:36:34.768 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:36:34.771 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:36:34.779 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:36:34.781 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:36:34.784 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:36:34.786 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
df = load_data()
st.write("🧾 Actual column names:")
st.write(df.columns.tolist())
# Out:
# 2025-04-14 05:52:25.632 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:25.648 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:25.652 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:25.658 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:25.664 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:25.667 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import streamlit as st
import pandas as pd

# Load data
@st.cache_data
def load_data():
    return pd.read_csv(r"C:\Users\SATHYA COMPUTERS\Documents\Custom Office Templates\imdb_2024_data.csv")

df = load_data()

# Show column names so you can verify
st.subheader("📋 Columns in the Dataset")
st.write(df.columns.tolist())

# Optional: display the first few rows
st.subheader("🔍 Sample Data")
st.write(df.head())

# ---- Stop here until you confirm column names ----
st.warning("⚠️ Please check the column names above. Tell me the exact name for genre and rating to proceed with visualizations.")
# Out:
# 2025-04-14 05:52:32.142 No runtime found, using MemoryCacheStorageManager
# 2025-04-14 05:52:32.155 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.160 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.164 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.166 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.169 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.174 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-04-14 05:52:32.183 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ...

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\SATHYA COMPUTERS\Documents\Custom Office Templates\imdb_2024_data.csv")
print(df.columns.tolist())
# Out:
# ['Movie Name', 'Genre', 'Ratings', 'Voting Counts', 'Duration']
