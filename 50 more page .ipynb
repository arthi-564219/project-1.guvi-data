# %%
path='//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span'

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import time

# Setup WebDriver (use chrome or firefox)
driver = webdriver.Chrome()  # or use webdriver.firefox()if  i prefer firefox
#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span
#open the IMDB page
driver.get("https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=adventure,action")

#wait for the page to load
time.sleep(3)

#define a function to click the "load more" button
def click_load_more():
    try:
        #locate the "load more"button//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')

        #scroll to the "load more" button to make sure it's in view
        ActionChains(driver).move_to_element(load_more_button).perform()

        #click the button
        load_more_button.click()

        #wait for new content to load
        time.sleep(3)
        return True
    except Exception as e:
        print("Error clicking 'load more' button:",e)
        return False 
    
#click "load more"until the button is no longer avaliable
while click_load_more():
    print("clicked 'load more' button")

#once the loop ends,we assume there is no more content to load
print("No more content to load.")

#optionally ,some can scrape the data the need in after of content is fully loaded.

#close the driver then done 
#driver.quir()
# Out:
# Error clicking 'load more' button: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span"}
#   (Session info: chrome=135.0.7049.85); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00007FF75F275335+78597]
# 	GetHandleVerifier [0x00007FF75F275390+78688]
# 	(No symbol) [0x00007FF75F0291AA]
# 	(No symbol) [0x00007FF75F07F149]
# 	(No symbol) [0x00007FF75F07F3FC]
# 	(No symbol) [0x00007FF75F0D2467]
# 	(No symbol) [0x00007FF75F0A712F]
# 	(No symbol) [0x00007FF75F0CF2BB]
# 	(No symbol) [0x00007FF75F0A6EC3]
# 	(No symbol) [0x00007FF75F0703F8]
# 	(No symbol) [0x00007FF75F071163]
# 	GetHandleVerifier [0x00007FF75F51EEED+2870973]
# 	GetHandleVerifier [0x00007FF75F519698+2848360]
# ...

# %%
movie_items = driver.find_elements(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li')#//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul

# %%
len('movie_items')
# Out:
# 11
